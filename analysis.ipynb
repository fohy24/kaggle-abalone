# %%
import numpy as np
import pandas as pd
import altair as alt
alt.data_transformers.enable("vegafusion")
# Out:
# DataTransformerRegistry.enable('vegafusion')

# %%
train_df = pd.read_csv('data/train.csv', index_col=0)
test_df = pd.read_csv('data/test.csv')
train_df.head()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# id
# 0    F   0.550     0.430   0.150        0.7715          0.3285
# 1    F   0.630     0.490   0.145        1.1300          0.4580
# 2    I   0.160     0.110   0.025        0.0210          0.0055
# 3    M   0.595     0.475   0.150        0.9145          0.3755
# 4    I   0.555     0.425   0.130        0.7820          0.3695
#
#     Whole weight.2  Shell weight  Rings
# id
# 0           0.1465        0.2400     11
# 1           0.2765        0.3200     11
# 2           0.0030        0.0050      6
# 3           0.2055        0.2500     10
# 4           0.1600        0.1975      9

# %%
# Truncated train_df
TRUNCATE = False

if TRUNCATE:
    train_df = train_df.query(f'Rings < {train_df['Rings'].quantile(0.997)}')

# %%
display(train_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90615 entries, 0 to 90614
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             90615 non-null  object
#  1   Length          90615 non-null  float64
#  2   Diameter        90615 non-null  float64
#  3   Height          90615 non-null  float64
#  4   Whole weight    90615 non-null  float64
#  5   Whole weight.1  90615 non-null  float64
#  6   Whole weight.2  90615 non-null  float64
#  7   Shell weight    90615 non-null  float64
#  8   Rings           90615 non-null  int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 6.9+ MB
# None

# %%
target_col = "Rings"
X_train, y_train = train_df.drop(
    columns=[target_col]), train_df[target_col]
y_train = pd.DataFrame(y_train)
X_test = test_df.copy()

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (90615, 8)
# (90615, 1)
# (60411, 9)

# %%
alt.Chart(y_train,
          title='Histogram of Ring').mark_bar().encode(
    alt.X('Rings:Q').bin(maxbins=40),
    y='count()'
)
# Out:
# alt.Chart(...)

# %%
y_train.quantile(0.995)
# Out:
# Rings    21.0
# Name: 0.995, dtype: float64

# %%
train_df.corr(numeric_only=True).round(
    decimals=3).style.background_gradient()
# Out:
# <style type="text/css">
# #T_85152_row0_col0, #T_85152_row1_col1, #T_85152_row2_col2, #T_85152_row3_col3, #T_85152_row4_col4, #T_85152_row5_col5, #T_85152_row6_col6, #T_85152_row7_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_85152_row0_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_85152_row0_col2, #T_85152_row4_col1 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_85152_row0_col3, #T_85152_row3_col0, #T_85152_row3_col1, #T_85152_row6_col4 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_85152_row0_col4 {
#   background-color: #04649e;
#   color: #f1f1f1;
# }
# #T_85152_row0_col5 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_85152_row0_col6 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_85152_row0_col7 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_85152_row1_col0 {
#   background-color: #023e62;
#   color: #f1f1f1;
# }
# #T_85152_row1_col2, #T_85152_row4_col0 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_85152_row1_col3 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_85152_row1_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_85152_row1_col5, #T_85152_row5_col6 {
#   background-color: #0568a3;
#   color: #f1f1f1;
# }
# #T_85152_row1_col6 {
#   background-color: #0c74b2;
#   color: #f1f1f1;
# }
# #T_85152_row1_col7 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_85152_row2_col0, #T_85152_row6_col1 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_85152_row2_col1 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_85152_row2_col3 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_85152_row2_col4 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_85152_row2_col5 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_85152_row2_col6 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_85152_row2_col7 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_85152_row3_col2 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_85152_row3_col4 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_85152_row3_col5 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_85152_row3_col6 {
#   background-color: #04588a;
#   color: #f1f1f1;
# }
# #T_85152_row3_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_85152_row4_col2 {
#   background-color: #4897c4;
#   color: #f1f1f1;
# }
# #T_85152_row4_col3 {
#   background-color: #034c78;
#   color: #f1f1f1;
# }
# #T_85152_row4_col5 {
#   background-color: #04598c;
#   color: #f1f1f1;
# }
# #T_85152_row4_col6, #T_85152_row6_col2 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_85152_row4_col7, #T_85152_row7_col0, #T_85152_row7_col1, #T_85152_row7_col2, #T_85152_row7_col3, #T_85152_row7_col4, #T_85152_row7_col5, #T_85152_row7_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_85152_row5_col0, #T_85152_row5_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_85152_row5_col2 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_85152_row5_col3 {
#   background-color: #034a74;
#   color: #f1f1f1;
# }
# #T_85152_row5_col4 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_85152_row5_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_85152_row6_col0 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_85152_row6_col3 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_85152_row6_col5 {
#   background-color: #045f95;
#   color: #f1f1f1;
# }
# #T_85152_row6_col7 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# </style>
# <table id="T_85152">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85152_level0_col0" class="col_heading level0 col0" >Length</th>
#       <th id="T_85152_level0_col1" class="col_heading level0 col1" >Diameter</th>
#       <th id="T_85152_level0_col2" class="col_heading level0 col2" >Height</th>
#       <th id="T_85152_level0_col3" class="col_heading level0 col3" >Whole weight</th>
#       <th id="T_85152_level0_col4" class="col_heading level0 col4" >Whole weight.1</th>
#       <th id="T_85152_level0_col5" class="col_heading level0 col5" >Whole weight.2</th>
#       <th id="T_85152_level0_col6" class="col_heading level0 col6" >Shell weight</th>
#       <th id="T_85152_level0_col7" class="col_heading level0 col7" >Rings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85152_level0_row0" class="row_heading level0 row0" >Length</th>
#       <td id="T_85152_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_85152_row0_col1" class="data row0 col1" >0.990000</td>
#       <td id="T_85152_row0_col2" class="data row0 col2" >0.916000</td>
#       <td id="T_85152_row0_col3" class="data row0 col3" >0.931000</td>
#       <td id="T_85152_row0_col4" class="data row0 col4" >0.910000</td>
#       <td id="T_85152_row0_col5" class="data row0 col5" >0.913000</td>
#       <td id="T_85152_row0_col6" class="data row0 col6" >0.911000</td>
#       <td id="T_85152_row0_col7" class="data row0 col7" >0.624000</td>
#     </tr>
#     <tr>
#       <th id="T_85152_level0_row1" class="row_heading level0 row1" >Diameter</th>
#       <td id="T_85152_row1_col0" class="data row1 col0" >0.990000</td>
#       <td id="T_85152_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_85152_row1_col2" class="data row1 col2" >0.920000</td>
#       <td id="T_85152_row1_col3" class="data row1 col3" >0.934000</td>
#       <td id="T_85152_row1_col4" class="data row1 col4" >0.908000</td>
#       <td id="T_85152_row1_col5" class="data row1 col5" >0.915000</td>
#       <td id="T_85152_row1_col6" class="data row1 col6" >0.918000</td>
#       <td id="T_85152_row1_col7" class="data row1 col7" >0.637000</td>
#     </tr>
#     <tr>
#       <th id="T_85152_level0_row2" class="row_heading level0 row2" >Height</th>
#       <td id="T_85152_row2_col0" class="data row2 col0" >0.916000</td>
#       <td id="T_85152_row2_col1" class="data row2 col1" >0.920000</td>
#       <td id="T_85152_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_85152_row2_col3" class="data row2 col3" >0.902000</td>
#       <td id="T_85152_row2_col4" class="data row2 col4" >0.862000</td>
#       <td id="T_85152_row2_col5" class="data row2 col5" >0.886000</td>
#       <td id="T_85152_row2_col6" class="data row2 col6" >0.904000</td>
#       <td id="T_85152_row2_col7" class="data row2 col7" >0.666000</td>
#     </tr>
#     <tr>
#       <th id="T_85152_level0_row3" class="row_heading level0 row3" >Whole weight</th>
#       <td id="T_85152_row3_col0" class="data row3 col0" >0.931000</td>
#       <td id="T_85152_row3_col1" class="data row3 col1" >0.934000</td>
#       <td id="T_85152_row3_col2" class="data row3 col2" >0.902000</td>
#       <td id="T_85152_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_85152_row3_col4" class="data row3 col4" >0.971000</td>
#       <td id="T_85152_row3_col5" class="data row3 col5" >0.974000</td>
#       <td id="T_85152_row3_col6" class="data row3 col6" >0.964000</td>
#       <td id="T_85152_row3_col7" class="data row3 col7" >0.617000</td>
#     </tr>
#     <tr>
#       <th id="T_85152_level0_row4" class="row_heading level0 row4" >Whole weight.1</th>
#       <td id="T_85152_row4_col0" class="data row4 col0" >0.910000</td>
#       <td id="T_85152_row4_col1" class="data row4 col1" >0.908000</td>
#       <td id="T_85152_row4_col2" class="data row4 col2" >0.862000</td>
#       <td id="T_85152_row4_col3" class="data row4 col3" >0.971000</td>
#       <td id="T_85152_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_85152_row4_col5" class="data row4 col5" >0.949000</td>
#       <td id="T_85152_row4_col6" class="data row4 col6" >0.912000</td>
#       <td id="T_85152_row4_col7" class="data row4 col7" >0.515000</td>
#     </tr>
#     <tr>
#       <th id="T_85152_level0_row5" class="row_heading level0 row5" >Whole weight.2</th>
#       <td id="T_85152_row5_col0" class="data row5 col0" >0.913000</td>
#       <td id="T_85152_row5_col1" class="data row5 col1" >0.915000</td>
#       <td id="T_85152_row5_col2" class="data row5 col2" >0.886000</td>
#       <td id="T_85152_row5_col3" class="data row5 col3" >0.974000</td>
#       <td id="T_85152_row5_col4" class="data row5 col4" >0.949000</td>
#       <td id="T_85152_row5_col5" class="data row5

# %%
# imports
import sys, os
import time

import numpy as np
import pandas as pd
import altair as alt
from IPython.display import HTML

sys.path.append(os.path.join(os.path.abspath("."), "code"))

from IPython.display import display

# Classifiers and regressors
from sklearn.dummy import DummyClassifier, DummyRegressor

# Preprocessing and pipeline
from sklearn.impute import SimpleImputer

# train test split and cross validation
from sklearn.model_selection import cross_val_score, cross_validate, train_test_split
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.preprocessing import (
    MinMaxScaler,
    RobustScaler,
    OneHotEncoder,

    
    OrdinalEncoder,
    StandardScaler,
)
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import *
from sklearn.tree import *
from sklearn.ensemble import *
from sklearn.svm import *
from lightgbm.sklearn import *
from sklearn.model_selection import *
from xgboost import XGBRegressor

# %%
# Function to quicly cross validate different models
def mean_std_cross_val_scores(model, X_train, y_train, **kwargs):
    """
    Returns mean and std of cross validation

    Parameters
    ----------
    model :
        scikit-learn model
    X_train : numpy array or pandas DataFrame
        X in the training data
    y_train :
        y in the training data

    Returns
    ----------
        pandas Series with mean scores from cross_validation
    """

    scores = cross_validate(model, X_train, y_train, n_jobs=-1, **kwargs)

    mean_scores = pd.DataFrame(scores).mean()
    std_scores = pd.DataFrame(scores).std()
    out_col = []

    for i in range(len(mean_scores)):
        out_col.append((f"%0.3f (+/- %0.3f)" %
                       (mean_scores.iloc[i], std_scores.iloc[i])))

    return pd.Series(data=out_col, index=mean_scores.index)

# %%
categorcial_feats = ['Sex']
numerical_feats = [col for col in X_train.columns if col not in ['Sex']]

categorical_pipe = make_pipeline(OneHotEncoder(drop='if_binary', handle_unknown='ignore'))
numerical_pipe = make_pipeline(RobustScaler(), SimpleImputer(strategy='median'))

preprocessor_with_scaler = make_column_transformer((categorical_pipe, categorcial_feats),
                                                    (numerical_pipe, numerical_feats))

print(categorcial_feats)
print(numerical_feats)
preprocessor_with_scaler
# Out:
# ['Sex']
# ['Length', 'Diameter', 'Height', 'Whole weight', 'Whole weight.1', 'Whole weight.2', 'Shell weight']
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('onehotencoder',
#                                                   OneHotEncoder(drop='if_binary',
#                                                                 handle_unknown='ignore'))]),
#                                  ['Sex']),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('robustscaler',
#                                                   RobustScaler()),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  ['Length', 'Diameter', 'Height',
#                                   'Whole weight', 'Whole weight.1',
#                                   'Whole weight.2', 'Shell weight'])])

# %%
train_df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Whole weight.1  \
# id
# 0       F   0.550     0.430   0.150        0.7715          0.3285
# 1       F   0.630     0.490   0.145        1.1300          0.4580
# 2       I   0.160     0.110   0.025        0.0210          0.0055
# 3       M   0.595     0.475   0.150        0.9145          0.3755
# 4       I   0.555     0.425   0.130        0.7820          0.3695
# ...    ..     ...       ...     ...           ...             ...
# 90610   M   0.335     0.235   0.075        0.1585          0.0685
# 90611   M   0.555     0.425   0.150        0.8790          0.3865
# 90612   I   0.435     0.330   0.095        0.3215          0.1510
# 90613   I   0.345     0.270   0.075        0.2000          0.0980
# 90614   I   0.425     0.325   0.100        0.3455          0.1525
#
#        Whole weight.2  Shell weight  Rings
# id
# 0              0.1465        0.2400     11
# 1              0.2765        0.3200     11
# 2              0.0030        0.0050      6
# 3              0.2055        0.2500     10
# 4              0.1600        0.1975      9
# ...               ...           ...    ...
# 90610          0.0370        0.0450      6
# 90611          0.1815        0.2400      9
# 90612          0.0785        0.0815      6
# 90613          0.0490        0.0700      6
# 90614          0.0785        0.1050      8
#
# [90615 rows x 9 columns]

# %%
# create a dictionary for storing model scores
results_dict = {}

# %%
xgboost = make_pipeline(preprocessor_with_scaler, XGBRegressor(objective='reg:gamma', # so that the predictions would be non-negative
                                                               random_state=123,
                                                               n_jobs=-1,
                                                               verbosity=0))
results_dict["xgboost"] = mean_std_cross_val_scores(
    xgboost, X_train, y_train, return_train_score=True,
    scoring='neg_root_mean_squared_log_error'
)
pd.DataFrame(results_dict).T
# Out:
#                   fit_time         score_time          test_score  \
# xgboost  0.771 (+/- 0.020)  0.040 (+/- 0.000)  -0.151 (+/- 0.002)
#
#                 train_score
# xgboost  -0.137 (+/- 0.001)

# %%
TUNING = True

# %%
param_grid = {
    "xgbregressor__learning_rate": np.arange(0.01, 0.1, 0.001),
    "xgbregressor__max_depth": np.arange(3, 8, 1),
    "xgbregressor__max_leaves": np.arange(100, 1001, 20),
    "xgbregressor__n_estimators": np.arange(100, 601, 20),
    "xgbregressor__gamma": np.arange(0, 10, 0.5),
    "xgbregressor__lambda": np.arange(0, 100, 0.5),
    "xgbregressor__alpha": np.arange(0, 100, 0.5),
    "xgbregressor__eta": np.arange(0.3, 1, 0.05),
    "xgbregressor__min_child_weight": np.arange(0, 10, 0.5),
    "xgbregressor__max_delta_step": np.arange(0, 10, 1),
    "xgbregressor__subsample": np.arange(0.3, 0.7, 0.02),
}

# %%
# Estimate runtime
if TUNING:
    random_search = RandomizedSearchCV(
    xgboost,
    param_distributions=param_grid,
    n_iter=5,
    n_jobs=-1,
    return_train_score=True,
    random_state=123,
    scoring='neg_root_mean_squared_log_error'
    )

    random_search.fit(X_train, y_train)

# %%
if TUNING:
    random_search = RandomizedSearchCV(
    xgboost,
    param_distributions=param_grid,
    n_iter=2500,
    n_jobs=-1,
    return_train_score=True,
    random_state=123,
    scoring='neg_root_mean_squared_log_error'
    )

    random_search.fit(X_train, y_train)

# %%
if TUNING:
    cv_result_df = pd.DataFrame(random_search.cv_results_)[
        [
            "mean_test_score",
            "param_xgbregressor__learning_rate",
            "param_xgbregressor__max_depth",
            "param_xgbregressor__max_leaves",
            "param_xgbregressor__n_estimators",
            "param_xgbregressor__gamma",
            "param_xgbregressor__lambda",
            "param_xgbregressor__alpha",
            "param_xgbregressor__eta",
            "param_xgbregressor__min_child_weight",
            "param_xgbregressor__max_delta_step",
            "param_xgbregressor__subsample",
            "mean_fit_time",
            "rank_test_score",
        ]
    ].set_index("rank_test_score").sort_index().T

    cv_result_df.to_csv('model/xgboost_cv_result.csv')
    cv_result_df
else:
    cv_result_df = pd.read_csv('model/xgboost_cv_result.csv', index_col=0)

cv_result_df
# Out:
# rank_test_score                           1         2         3         4     \
# mean_test_score                      -0.149462 -0.149556 -0.149689 -0.149951
# param_xgbregressor__learning_rate        0.097     0.074     0.097     0.095
# param_xgbregressor__max_depth                7         7         7         5
# param_xgbregressor__max_leaves             380       320       340       140
# param_xgbregressor__n_estimators           600       400       200       580
# param_xgbregressor__gamma                  0.0       0.0       0.0       0.0
# param_xgbregressor__lambda                80.0      55.0      90.0      11.5
# param_xgbregressor__alpha                  8.5       6.5       1.5      16.5
# param_xgbregressor__eta                   0.55      0.65       0.5       0.7
# param_xgbregressor__min_child_weight       7.0       1.0       3.0       2.5
# param_xgbregressor__max_delta_step           0         2         3         4
# param_xgbregressor__subsample             0.52      0.44       0.4      0.68
# mean_fit_time                         7.612199  5.141526  2.702791  6.333745
#
# rank_test_score                           5         6         7         8     \
# mean_test_score                       -0.14996  -0.14997 -0.150179 -0.150356
# param_xgbregressor__learning_rate        0.043     0.085     0.048     0.086
# param_xgbregressor__max_depth                6         5         6         5
# param_xgbregressor__max_leaves             840       380       820       300
# param_xgbregressor__n_estimators           360       260       600       400
# param_xgbregressor__gamma                  0.0       0.0       0.0       0.0
# param_xgbregressor__lambda                71.0      62.5      72.5      69.5
# param_xgbregressor__alpha                  3.5       2.0      17.0      15.5
# param_xgbregressor__eta                    0.7      0.95       0.9       0.6
# param_xgbregressor__min_child_weight       5.5       4.5       3.0       3.5
# param_xgbregressor__max_delta_step           6         2         1         0
# param_xgbregressor__subsample             0.54      0.38      0.62       0.6
# mean_fit_time                         4.430321  2.914331  6.986053  4.604635
#
# rank_test_score                           9         10    ...      2491  \
# mean_test_score                      -0.150383 -0.150389  ... -0.495117
# param_xgbregressor__learning_rate        0.089     0.064  ...     0.012
# param_xgbregressor__max_depth                6         4  ...         3
# param_xgbregressor__max_leaves             200       660  ...       500
# param_xgbregressor__n_estimators           360       540  ...       120
# param_xgbregressor__gamma                  0.0       0.0  ...       8.0
# param_xgbregressor__lambda                68.0      79.5  ...      78.0
# param_xgbregressor__alpha                 19.0      11.0  ...      35.5
# param_xgbregressor__eta                    0.4       0.7  ...      0.55
# param_xgbregressor__min_child_weight       4.0       9.0  ...       8.0
# param_xgbregressor__max_delta_step           9         5  ...         8
# param_xgbregressor__subsample             0.58      0.56  ...       0.6
# mean_fit_time                         4.263208  5.513609  ...  1.381252
#
# rank_test_score                           2492      2493      2494      2495  \
# mean_test_score                      -0.495772 -0.508348 -0.535022 -0.535418
# param_xgbregressor__learning_rate        0.012     0.014     0.011     0.011
# param_xgbregressor__max_depth                3         7         6         6
# param_xgbregressor__max_leaves             100       520       660       540
# param_xgbregressor__n_estimators           120       100       120       120
# param_xgbregressor__gamma                  5.0       4.5       2.0       1.5
# param_xgbregressor__lambda                20.5      45.0      51.5      86.0
# param_xgbregressor__alpha                 86.5      36.0      17.0      11.0
# param_xgbregressor__eta                   0.95      0.75      0.35      0.85
# param_xgbregressor__min_child_weight       1.0       0.0       1.0       0.0
# param_xgbregressor__max_delta_step           0         8         3         2
# param_xgbregressor__subsample             0.64      0.46      0.46      0.44
# mean_fit_time                         1.303333  1.202116  1.386327  1.351483
#
# rank_test_score                           2496      2497      2498      2499  \
# mean_test_score                      -0.539524 -0.540743 -0.545073 -0.579062
# param_xgbregressor__learning_rate        0.011     0.011     0.013     0.012
# param_xgbregressor__max_depth                3         6         5         5
# param_xgbregressor__max_leaves             480       200       240       860
# param_xgbregressor__n_estimators           120       120       100       100
# param_xgbregressor__gamma                  0.5       3.0       3.0       5.0
# param_xgbregressor__lambda                85.5      13.5      55.0      74.0
# param_xgbregressor__alpha                 84.0      97.5      82.5      66.0
# param_xgbregressor__eta                   0.35      0.65      0.45       0.5
# param_xgbregressor__min_child_weight       1.0       2.5       3.0       2.0
# param_xgbregressor__max_delta_step           7         1         1         5
# param_xgbregressor__subsample             0.32      0.46       0.4      0.68
# mean_fit_time                         1.398737  1.481703  1.160328  1.172755
#
# rank_test_score                           2500
# mean_test_score                      -0.617962
# param_xgbregressor__learning_rate        0.011
# param_xgbregressor__max_depth                3
# param_xgbregressor__max_leaves             580
# param_xgbregressor__n_estimators           100
# param_xgbregressor__gamma                  7.5
# param_xgbregressor__lambda                82.0
# param_xgbregressor__alpha                 46.0
# param_xgbregressor__eta                    0.7
# param_xgbregressor__min_child_weight       7.0
# param_xgbregressor__max_delta_step           7
# param_xgbregressor__subsample             0.32
# mean_fit_time                         1.093855
#
# [13 rows x 2500 columns]

# %%
fig_hyperparam = alt.Chart(cv_result_df.T).mark_point(clip=True).encode(
    x = alt.X('mean_test_score'), #.scale(domain=(0.58, 0.7)),
    y=alt.Y(alt.repeat("row"), type='quantitative')
).properties(
    width=900
).repeat(
    row=cv_result_df.T.columns.to_list()[1:-1]
)

fig_hyperparam
# Out:
# alt.RepeatChart(...)

# %%
import pickle

if TUNING:
    xgboost_opt = make_pipeline(random_search.best_estimator_)
else:
    with open('model/xgboost_opt.pkl', 'rb') as file:
        xgboost_opt = pickle.load(file)   
    xgboost_opt = make_pipeline(xgboost_opt)
                            
results_dict["xgboost optimized"] = mean_std_cross_val_scores(
    xgboost_opt, X_train, y_train, return_train_score=True,
    scoring='neg_root_mean_squared_log_error'
)
pd.DataFrame(results_dict).T
# Out:
#                             fit_time         score_time          test_score  \
# xgboost            0.771 (+/- 0.020)  0.040 (+/- 0.000)  -0.151 (+/- 0.002)
# xgboost optimized  4.747 (+/- 0.029)  0.264 (+/- 0.002)  -0.149 (+/- 0.002)
#
#                           train_score
# xgboost            -0.137 (+/- 0.001)
# xgboost optimized  -0.144 (+/- 0.000)

# %%
# Fit the optimized model
xgboost_opt.fit(X_train, y_train)

if TUNING:
    # Save the model to a pickle file
    with open('model/xgboost_opt_gamma_truncated_0.99.pkl', 'wb') as file:
        pickle.dump(xgboost_opt, file)

xgboost_opt
# Out:
# Pipeline(steps=[('pipeline',
#                  Pipeline(steps=[('columntransformer',
#                                   ColumnTransformer(transformers=[('pipeline-1',
#                                                                    Pipeline(steps=[('onehotencoder',
#                                                                                     OneHotEncoder(drop='if_binary',
#                                                                                                   handle_unknown='ignore'))]),
#                                                                    ['Sex']),
#                                                                   ('pipeline-2',
#                                                                    Pipeline(steps=[('robustscaler',
#                                                                                     RobustScaler()),
#                                                                                    ('simpleimputer',
#                                                                                     SimpleImputer(strategy='median'))]),
#                                                                    ['Length',
#                                                                     'Diameter',
#                                                                     'H...
#                                                feature_types=None, gamma=0.0,
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                lambda=80.0,
#                                                learning_rate=0.09699999999999992,
#                                                max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=0, max_depth=7,
#                                                max_leaves=380,
#                                                min_child_weight=7.0,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=600, ...))]))])

# %%
xgboost_opt.predict(X_test).max()
# Out:
# 19.934395

# %%
xgboost_opt.predict(X_train)
# Out:
# array([10.197204 , 10.837562 ,  4.0627966, ...,  6.951442 ,  6.8155866,
#         7.5976353], dtype=float32)

# %%
pred = X_test.copy()
pred['Rings'] = xgboost_opt.predict(X_test)
pred[['Rings']].shape
# Out:
# (60411, 1)

# %%
pred[['id', 'Rings']].to_csv('prediction/xgboost_opt_gamma_truncated_0.997.csv', index=False)
